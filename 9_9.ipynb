# %% [markdown]
# <a href="https://colab.research.google.com/github/Leehj0922/10818/blob/main/9_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=6
b=1.5
c=1+2j
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(a+1, type(a+1))# 정수+ 정수=정수
print(a/b, type(a/b))# 정수/ 실수=실수
print(a/2, type(a/2))# 정수 / 정수=실수
print(a//2, type(a//2))# 정수 // 정수=정수
# Out:
# 6 <class 'int'>
# 1.5 <class 'float'>
# (1+2j) <class 'complex'>
# 7 <class 'int'>
# 4.0 <class 'float'>
# 3.0 <class 'float'>
# 3 <class 'int'>

# %%
a= True
b= False
print(a,type(a))
print(b,type(b))
print(10<20, type(10<20))
print(20<10, type(20<10))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>

# %%
a='Hello'
b=''
c=10
d=0
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# False
# True
# False

# %%
a='100'
b='Python'
c='name is "짱구"'
d='''name is "코난"'''
print(a, type(a))
print(a, type(b))
print(a, type(c))
print(a, type(d))
# Out:
# 100 <class 'str'>
# 100 <class 'str'>
# 100 <class 'str'>
# 100 <class 'str'>

# %%
a= 'hello'
b= 'world'
print(a+b)
print(a*3)
print(a<b)
print('h'in a)
print('wor'not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a= 'Hello Python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
a='Hello Python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# Python
# Hello
# Py
# HloPt

# %%
jumin=input('주민등록번호 입력:')


print('연:20'+ jumin[0:2]+'년')
print('연:'+ jumin[2:4]+'월')
print('연:'+ jumin[4:6]+'일')
# Out:
# 주민등록번호 입력:100922
# 연:2010년
# 연:09월
# 연:22일
