# %% [markdown]
# <a href="https://colab.research.google.com/github/Leehj0922/10818/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime, date, time
print('<디데이(D-day) 프로그램>')
print()

# %%
a= int(input('빨간색 접시의 개수를 입력:'))
b= int(input('파랑색 접시의 개수를 입력:'))
c= int(input('노란색 접시의 개수를 입력:'))
록
￦d= int(input('초록색 접시의 개수를 입력:'))
