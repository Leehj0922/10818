# %% [markdown]
# <a href="https://colab.research.google.com/github/Leehj0922/10818/blob/main/2026_09_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a={}
b={88:'seoul',24:'paris','num':[10,20]}
c={'name':'kim','name':'lee'}
print(a,type(a))
print(len(b))
print(b[88])
print(c['name'])
# Out:
# {} <class 'dict'>
# 3
# seoul
# lee

# %%
a={88:'london',20:'tokyo'}
a[88]='seoul'
a[24]='paris'
del a[20]
a.update({24:'busan'})
a.update({30:'suwon'})
print(a)
# Out:
# {88: 'seoul', 24: 'busan', 30: 'suwon'}

# %%
dic={'grape':'포도','apple':'사과'}
print(dic)
print(sorted(dic, reverse=True))
print(sorted(dic.items()))
print('apple' in dic)
print(dic.items())
print(dic.get('apple','gg'))
# Out:
# {'grape': '포도', 'apple': '사과'}
# ['grape', 'apple']
# [('apple', '사과'), ('grape', '포도')]
# True
# dict_items([('grape', '포도'), ('apple', '사과')])
# 사과

# %%
print(dic.keys())
print(dic.valudes())
print(sorted(dic.values()))
print(dic.items())

p=dic.pop('apple')
print(p)
print(dic)

print(dic.get('grape'))
print(dic.get('apple'))
print(dic.get('apple','없음'))

dic.clear()
print(dic)
# Out:
# dict_keys(['grape', 'apple'])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7376/3545124585.py in <cell line: 0>()
#       1 print(dic.keys())
# ----> 2 print(dic.valudes())
#       3 print(sorted(dic.values()))
#       4 print(dic.items())
#       5 p=dic.pop('apple')
#
# AttributeError: 'dict' object has no attribute 'valudes'

# %%
menu={'burger':5000,'pizza':8000,'pasta':7000}
menu['pizza']=8500
menu['chicken']=10000
del menu['pasta']
print(menu)
print('가격 역순 정리:',sorted(menu.values(),reverse=True))
# Out:
# {'burger': 5000, 'pizza': 8500, 'chicken': 10000}
# 가격 역순 정리: [10000, 8500, 5000]
