# %% [markdown]
# <a href="https://colab.research.google.com/github/Leehj0922/10818/blob/main/2026_09_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=set()
s1={3,2,2}
s2={9,1,3}
print(s1)
print(s2)
# Out:
# {2, 3}
# {9, 3, 1}

# %%
s1.add(10)
print(s1)

s1.update[(2,1)]
print(s1)

s1.discard(10)
print(s1)

s1.remove(3)
print(s1)

print(s1.intersection(s2))
print(s1.union(s2))
print(s1.differnce(s2))

s1.clear()
print(s1)

# %%
a=['우유','빵','버터','치즈','우유']
b=['빵','과일','야채','버터','우유','커피']
print(set(a))
print(set(a)&set(b))
# Out:
# {'버터', '우유', '치즈', '빵'}
# {'버터', '우유', '빵'}
