# %% [markdown]
# <a href="https://colab.research.google.com/github/Leehj0922/10818/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print('###########################')
print('[한양과학기술고등학교 학생학생증]')
a = input('*학번:')
b = input('*성명:')
c = input('*소속:')
print('위 사람은 본 학교의 학생임을 증명함')
print('###########################')
# Out:
# ###########################
# [한양과학기술고등학교 학생학생증]
# *학번:10818
# *성명:이현중
# *소속:스마트전자과
# 위 사람은 본 학교의 학생임을 증명함
# ###########################
